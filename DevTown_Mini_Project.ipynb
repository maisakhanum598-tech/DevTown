# %% [markdown]
# <a href="https://colab.research.google.com/github/maisakhanum598-tech/DevTown/blob/main/DevTown_Mini_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#1.Load the Data
df=pd.read_csv("Amazon.csv")
df.head()
# Out:
#       OrderID   OrderDate  CustomerID   CustomerName ProductID  \
# 0  ORD0000001  2023-01-31  CUST001504  Vihaan Sharma    P00014
# 1  ORD0000002  2023-12-30  CUST000178    Pooja Kumar    P00040
# 2  ORD0000003  2022-05-10  CUST047516    Sneha Singh    P00044
# 3  ORD0000004  2023-07-18  CUST030059   Vihaan Reddy    P00041
# 4  ORD0000005  2023-02-04  CUST048677  Aditya Kapoor    P00029
#
#            ProductName        Category       Brand  Quantity  UnitPrice  \
# 0           Drone Mini           Books   BrightLux         3     106.59
# 1           Microphone  Home & Kitchen  UrbanStyle         1     251.37
# 2  Power Bank 20000mAh        Clothing  UrbanStyle         3      35.03
# 3       Webcam Full HD  Home & Kitchen      Zenith         5      33.58
# 4              T-Shirt        Clothing    KiddoFun         2     515.64
#
#    Discount    Tax  ShippingCost  TotalAmount     PaymentMethod OrderStatus  \
# ...

# %%
#2.Display
df.shape
# Out:
# (100000, 20)

# %%
df.columns
# Out:
# Index(['OrderID', 'OrderDate', 'CustomerID', 'CustomerName', 'ProductID',
#        'ProductName', 'Category', 'Brand', 'Quantity', 'UnitPrice', 'Discount',
#        'Tax', 'ShippingCost', 'TotalAmount', 'PaymentMethod', 'OrderStatus',
#        'City', 'State', 'Country', 'SellerID'],
#       dtype='object')

# %%
df.dtypes
# Out:
# OrderID           object
# OrderDate         object
# CustomerID        object
# CustomerName      object
# ProductID         object
# ProductName       object
# Category          object
# Brand             object
# Quantity           int64
# UnitPrice        float64
# Discount         float64
# Tax              float64
# ShippingCost     float64
# TotalAmount      float64
# PaymentMethod     object
# OrderStatus       object
# City              object
# State             object
# Country           object
# SellerID          object
# dtype: object

# %%
df.describe()
# Out:
#             Quantity      UnitPrice       Discount            Tax  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        3.001400     302.905748       0.074226      68.468902
# std         1.413548     171.840797       0.082583      74.131180
# min         1.000000       5.000000       0.000000       0.000000
# 25%         2.000000     154.190000       0.000000      15.920000
# 50%         3.000000     303.070000       0.050000      45.250000
# 75%         4.000000     451.500000       0.100000      96.060000
# max         5.000000     599.990000       0.300000     538.460000
#
#         ShippingCost    TotalAmount
# count  100000.000000  100000.000000
# mean        7.406660     918.256479
# std         4.324057     724.508332
# min         0.000000       4.270000
# 25%         3.680000     340.890000
# 50%         7.300000     714.315000
# 75%        11.150000    1349.765000
# max        15.000000    3534.980000

# %%
#3.KPI Analysis
print("Total amount =",df['TotalAmount'].sum())
print("Total Orders =",df['Quantity'].count() )
print("Average Sales =",df['TotalAmount'].mean())
print("Maximum Sales =",df['TotalAmount'].max())
print("Minimum Sales =",df['TotalAmount'].min())
# Out:
# Total amount = 91825647.92
# Total Orders = 100000
# Average Sales = 918.2564792000001
# Maximum Sales = 3534.98
# Minimum Sales = 4.27

# %%
#4.Sales Analysis
df.groupby('State')['TotalAmount'].sum().sort_values(ascending=False)
# Out:
# State
# TX    22862540.54
# CA    18231196.79
# NC     4747701.73
# WA     4660962.17
# PA     4650673.88
# CO     4638498.97
# IL     4632847.44
# OH     4615442.32
# IN     4609048.43
# FL     4597177.27
# NY     4554358.08
# DC     4520876.11
# AZ     4504324.19
# Name: TotalAmount, dtype: float64

# %%
#5.Sales Analysis
df.groupby('Category')['TotalAmount'].sum()
# Out:
# Category
# Books                15261837.01
# Clothing             15253397.50
# Electronics          15584217.18
# Home & Kitchen       15163939.36
# Sports & Outdoors    15345571.88
# Toys & Games         15216684.99
# Name: TotalAmount, dtype: float64

# %%
#7.Sales Analysis
df.groupby('ProductName')['TotalAmount'].sum().sort_values(ascending=False)
# Out:
# ProductName
# Memory Card 128GB              1935138.40
# LED Desk Lamp                  1921948.41
# Mechanical Keyboard            1906963.54
# Electric Kettle                1905751.79
# Smartwatch                     1901275.59
# Dress Shirt                    1896765.36
# Water Bottle                   1895467.95
# Gaming Mouse                   1895103.98
# Kids Toy Car                   1891082.43
# Jeans                          1882591.82
# Noise Cancelling Headphones    1881108.57
# Cookware Set                   1877038.73
# Smartphone Case                1875421.41
# Microphone                     1871740.68
# Smart Light Bulb               1868940.58
# 4K Monitor                     1866774.35
# Phone Tripod                   1866256.31
# Board Game                     1863310.96
# Vacuum Cleaner                 1855117.83
# Router                         1850756.20
# Laptop Sleeve                  1848297.80
# Yoga Mat                       1847898.09
# ...

# %%
#9.Customer and Product Analysis
df.groupby('CustomerName')['TotalAmount'].sum().sort_values(ascending=False).head()
# Out:
# CustomerName
# Pooja Kapoor    547832.64
# Vihaan Singh    526675.89
# Pooja Singh     516451.45
# Kabir Joshi     515361.68
# Aditya Gupta    515005.09
# Name: TotalAmount, dtype: float64

# %%
#10.Customer and Product Analysis
df.groupby('ProductName')['Quantity'].sum()
# Out:
# ProductName
# 4K Monitor                     6111
# Action Camera                  6104
# Air Fryer                      5956
# Backpack                       5848
# Bluetooth Speaker              5782
# Board Game                     6200
# Car Charger                    5754
# Children's Book                5619
# Cookware Set                   6130
# Desk Organizer                 6079
# Desk Plant                     5847
# Dress Shirt                    5960
# Drone Mini                     5975
# Electric Kettle                6165
# External HDD 2TB               5858
# Fitness Band                   5724
# Gaming Mouse                   6170
# Graphic Tablet                 5789
# HDMI Cable 2m                  5985
# Instant Pot                    6016
# Jeans                          6037
# Kids Toy Car                   6131
# LED Desk Lamp                  6344
# Laptop Sleeve                  5992
# Mechanical Keyboard            6161
# ...

# %%
#11.Payment Analysis
df.groupby('PaymentMethod')['OrderID'].count()
# Out:
# PaymentMethod
# Amazon Pay          15017
# Cash on Delivery     4928
# Credit Card         35038
# Debit Card          20024
# Net Banking          9927
# UPI                 15066
# Name: OrderID, dtype: int64

# %%
#12.Time Based Analysis
df['OrderDate'] = pd.to_datetime(df['OrderDate'])
df['Month'] = df['OrderDate'].dt.month
df.groupby('Month')['TotalAmount'].sum()
# Out:
# Month
# 1     7883801.27
# 2     6931724.49
# 3     7766527.73
# 4     7646203.22
# 5     7864283.27
# 6     7654636.75
# 7     7737925.51
# 8     7890598.37
# 9     7558970.85
# 10    7654243.32
# 11    7495754.13
# 12    7740979.01
# Name: TotalAmount, dtype: float64

# %%
#13.Multi-Level Analysis
df.groupby(['State','Category'])['TotalAmount'].sum()
# Out:
# State  Category
# AZ     Books                793211.33
#        Clothing             691249.82
#        Electronics          747955.37
#        Home & Kitchen       737616.34
#        Sports & Outdoors    694318.06
#                               ...
# WA     Clothing             747668.70
#        Electronics          879580.90
#        Home & Kitchen       809448.28
#        Sports & Outdoors    807282.60
#        Toys & Games         711514.12
# Name: TotalAmount, Length: 78, dtype: float64

# %%
#15.Visualization
df.groupby('State')['TotalAmount'].sum().plot(kind='bar')
plt.title("Revenue by State")
plt.xlabel("State")
plt.ylabel("Total Amount")
plt.show()

# %%
#16.Visualization
df.groupby('Category')['TotalAmount'].sum().plot(kind='pie')
plt.title("Revenue by Category")
plt.show()

# %%
#17. Visualization
monthly_sales.plot(kind='line')
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.show()

# %%
#18.Visualization
df.groupby('ProductName')['TotalAmount'].sum().sort_values(ascending=False).head(10).plot(kind='barh')
plt.title("Top 10 Products by Revenue")
plt.xlabel("Total Amount")
plt.ylabel("Product Name")
plt.show()

# %% [markdown]
# #Answer1
# Total Sales is 91825647.92
#
# #Answer2
# Highest - TX
# Lowest - IN
#
# #Answer3
# Electronics contributed highest to the revenue
#
# #Answer4
# Memory Card 128GB	1935138.40
# LED Desk Lamp	1921948.41
# Mechanical Keyboard	1906963.54
# Electric Kettle	1905751.79
# Smartwatch	1901275.59
# Dress Shirt	1896765.36
# Water Bottle	1895467.95
# Gaming Mouse	1895103.98
# Kids Toy Car	1891082.43
# Jeans	1882591.82
# #Answer1
# Total Sales is 91825647.92
#
# #Answer2
# Highest - TX
# Lowest - IN
#
# #Answer3
# Electronics contributed highest to the revenue
#
# #Answer4
# 1. Memory Card 128GB 	1935138.40
# 2. LED Desk Lamp	      1921948.41
# 3. Mechanical Keyboard	1906963.54
# 4. Electric Kettle	    1905751.79
# 5. Smartwatch	        1901275.59
# 6. Dress Shirt	        1896765.36
# 7. Water Bottle	      1895467.95
# 8. Gaming Mouse	      1895103.98
# 9. Kids Toy Car	      1891082.43
# 10. Jeans	              1882591.82
#
# #Answer5
#
#
# 1. Pooja Kapoor	547832.64
# 2. Vihaan Singh	526675.89
# 3. Pooja Singh	516451.45
# 4. Kabir Joshi	515361.68
# 5. Aditya Gupta	515005.09
#
# #Answer6
# Most preffered Payment Method is CreditCard
#
# #Answer7
# Month with highest sales is August
#
# #Answer8
# Electronics Category and Memory Card 128GB product is the highest
#
# #Answer9
# AZ and San Diego need improvment.
#
# We should offer region specific products or increase marketing etc.
#
# #Answer10
# We should increase our sales in underperforming states/cities
#
# Invest more in top performing categories/products

# %%
print("Total amount =",df['TotalAmount'].sum())
print("Total Orders =",df['Quantity'].count() )
print("Average Sales =",df['TotalAmount'].mean())
print("Maximum Quantity =",df['Quantity'].max())
print("Maximum Sales =",df['TotalAmount'].max())
print("Minimum Sales =",df['TotalAmount'].min())
# Out:
# Total amount = 91825647.92
# Total Orders = 100000
# Average Sales = 918.2564792000001
# Maximum Quantity = 5
# Maximum Sales = 3534.98
# Minimum Sales = 4.27

# %%
df.groupby('Category')['TotalAmount'].sum().sort_values(ascending=False)
# Out:
# Category
# Electronics          15584217.18
# Sports & Outdoors    15345571.88
# Books                15261837.01
# Clothing             15253397.50
# Toys & Games         15216684.99
# Home & Kitchen       15163939.36
# Name: TotalAmount, dtype: float64

# %%
df.groupby('ProductName')['TotalAmount'].sum().sort_values(ascending=False).head(10)
# Out:
# ProductName
# Memory Card 128GB      1935138.40
# LED Desk Lamp          1921948.41
# Mechanical Keyboard    1906963.54
# Electric Kettle        1905751.79
# Smartwatch             1901275.59
# Dress Shirt            1896765.36
# Water Bottle           1895467.95
# Gaming Mouse           1895103.98
# Kids Toy Car           1891082.43
# Jeans                  1882591.82
# Name: TotalAmount, dtype: float64

# %%
df.groupby('CustomerName')['TotalAmount'].sum().sort_values(ascending=False).head()
# Out:
# CustomerName
# Pooja Kapoor    547832.64
# Vihaan Singh    526675.89
# Pooja Singh     516451.45
# Kabir Joshi     515361.68
# Aditya Gupta    515005.09
# Name: TotalAmount, dtype: float64

# %%
df.groupby('PaymentMethod')['OrderID'].count().sort_values(ascending=False)
# Out:
# PaymentMethod
# Credit Card         35038
# Debit Card          20024
# UPI                 15066
# Amazon Pay          15017
# Net Banking          9927
# Cash on Delivery     4928
# Name: OrderID, dtype: int64

# %%
df.groupby('State')['TotalAmount'].sum().sort_values()
# Out:
# State
# AZ     4504324.19
# DC     4520876.11
# NY     4554358.08
# FL     4597177.27
# IN     4609048.43
# OH     4615442.32
# IL     4632847.44
# CO     4638498.97
# PA     4650673.88
# WA     4660962.17
# NC     4747701.73
# CA    18231196.79
# TX    22862540.54
# Name: TotalAmount, dtype: float64

# %%
df.groupby('City')['TotalAmount'].sum().sort_values()
# Out:
# City
# San Diego        4428865.07
# Houston          4485649.04
# Fort Worth       4502058.68
# Phoenix          4504324.19
# San Antonio      4506320.97
# San Francisco    4512087.61
# Washington       4520876.11
# New York         4554358.08
# Jacksonville     4597177.27
# Indianapolis     4609048.43
# Columbus         4615442.32
# Los Angeles      4620629.78
# Chicago          4632847.44
# Austin           4638403.18
# Denver           4638498.97
# Philadelphia     4650673.88
# Seattle          4660962.17
# San Jose         4669614.33
# Dallas           4730108.67
# Charlotte        4747701.73
# Name: TotalAmount, dtype: float64
